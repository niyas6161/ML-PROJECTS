# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/stroke.csv')

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
df.shape
# Out:
# (5110, 12)

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]>

# %%
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df['bmi']=df['bmi'].fillna(df['bmi']).mean()

# %%
df.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 0           Private          Urban             228.69  28.893237
# 1     Self-employed          Rural             202.21  28.893237
# 2           Private          Rural             105.92  28.893237
# 3           Private          Urban             171.23  28.893237
# 4     Self-employed          Rural             174.12  28.893237
# ...             ...            ...                ...        ...
# 5105        Private          Urban              83.75  28.893237
# 5106  Self-employed          Urban             125.20  28.893237
# 5107  Self-employed          Rural              82.99  28.893237
# 5108        Private          Rural             166.29  28.893237
# 5109       Govt_job          Urban              85.28  28.893237
#
#        smoking_status  stroke
# 0     formerly smoked       1
# 1        never smoked       1
# 2        never smoked       1
# 3              smokes       1
# 4        never smoked       1
# ...               ...     ...
# 5105     never smoked       0
# 5106     never smoked       0
# 5107     never smoked       0
# 5108  formerly smoked       0
# 5109          Unknown       0
#
# [5110 rows x 12 columns]

# %%
df.drop(['id'],axis=1,inplace=True)

# %%
df['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='gender')
plt.show()

# %%
df['age'].value_counts()
# Out:
# 78.00    102
# 57.00     95
# 52.00     90
# 54.00     87
# 51.00     86
#         ...
# 1.40       3
# 0.48       3
# 0.16       3
# 0.40       2
# 0.08       2
# Name: age, Length: 104, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='age')
plt.show()

# %%
df['hypertension'].value_counts()
# Out:
# 0    4612
# 1     498
# Name: hypertension, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='hypertension')
plt.show()

# %%
df['heart_disease'].value_counts()
# Out:
# 0    4834
# 1     276
# Name: heart_disease, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='heart_disease')
plt.show()

# %%
df['ever_married'].value_counts()
# Out:
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df, x='ever_married')
plt.show()

# %%
df['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children', 'Never_worked'],
#       dtype=object)

# %%
df['work_type'].value_counts()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
sns.countplot(data=df, x='work_type', hue='stroke')
plt.show()

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.276398       0.263796           0.238171
# hypertension       0.276398      1.000000       0.108306           0.174474
# heart_disease      0.263796      0.108306       1.000000           0.161857
# avg_glucose_level  0.238171      0.174474       0.161857           1.000000
# bmi                     NaN           NaN            NaN                NaN
# stroke             0.245257      0.127904       0.134914           0.131945
#
#                    bmi    stroke
# age                NaN  0.245257
# hypertension       NaN  0.127904
# heart_disease      NaN  0.134914
# avg_glucose_level  NaN  0.131945
# bmi                NaN       NaN
# stroke             NaN  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
lst=['gender','work_type','Residence_type','smoking_status','ever_married']
for i in lst:
  df[i]=le.fit_transform(df[i])
  df

# %%
df.dtypes
# Out:
# gender                 int64
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married           int64
# work_type              int64
# Residence_type         int64
# avg_glucose_level    float64
# bmi                  float64
# smoking_status         int64
# stroke                 int64
# dtype: object

# %%
x=df.iloc[:,:-1]
x
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0          1  67.0             0              1             1          2
# 1          0  61.0             0              0             1          3
# 2          1  80.0             0              1             1          2
# 3          0  49.0             0              0             1          2
# 4          0  79.0             1              0             1          3
# ...      ...   ...           ...            ...           ...        ...
# 5105       0  80.0             1              0             1          2
# 5106       0  81.0             0              0             1          3
# 5107       0  35.0             0              0             1          3
# 5108       1  51.0             0              0             1          2
# 5109       0  44.0             0              0             1          0
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# 0                  1             228.69  28.893237               1
# 1                  0             202.21  28.893237               2
# 2                  0             105.92  28.893237               2
# 3                  1             171.23  28.893237               3
# 4                  0             174.12  28.893237               2
# ...              ...                ...        ...             ...
# 5105               1              83.75  28.893237               2
# 5106               1             125.20  28.893237               2
# 5107               0              82.99  28.893237               2
# 5108               0             166.29  28.893237               1
# 5109               1              85.28  28.893237               0
#
# [5110 rows x 10 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5105    0
# 5106    0
# 5107    0
# 5108    0
# 5109    0
# Name: stroke, Length: 5110, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=10)
x_train
# Out:
#       gender   age  hypertension  heart_disease  ever_married  work_type  \
# 2285       1  49.0             0              0             1          2
# 4733       1  67.0             0              0             1          2
# 3905       1  78.0             0              0             1          2
# 4700       1  47.0             0              0             1          2
# 4939       0  59.0             0              0             1          2
# ...      ...   ...           ...            ...           ...        ...
# 1180       0  62.0             0              0             1          2
# 3441       0  59.0             0              0             1          3
# 1344       1  47.0             0              0             1          2
# 4623       1  25.0             0              0             1          0
# 1289       0  80.0             0              0             1          3
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# 2285               0              79.64  28.893237               3
# 4733               0              83.16  28.893237               1
# 3905               1             208.85  28.893237               1
# 4700               0             110.14  28.893237               3
# 4939               1              71.08  28.893237               2
# ...              ...                ...        ...             ...
# 1180               0              82.57  28.893237               1
# 3441               1              90.06  28.893237               3
# 1344               0              86.37  28.893237               3
# 4623               1             166.38  28.893237               2
# 1289               0              72.61  28.893237               2
#
# [4088 rows x 10 columns]

# %%
x_test
# Out:
#       gender    age  hypertension  heart_disease  ever_married  work_type  \
# 2413       0  58.00             0              0             1          2
# 1141       1  57.00             0              0             1          2
# 146        1  65.00             0              0             1          3
# 3883       0   1.64             0              0             0          4
# 1044       0  79.00             0              0             1          0
# ...      ...    ...           ...            ...           ...        ...
# 2261       1  59.00             0              0             1          2
# 4712       1  57.00             0              0             1          2
# 4971       0  63.00             0              0             1          2
# 2224       1  57.00             0              0             1          2
# 4825       0  14.00             0              0             0          4
#
#       Residence_type  avg_glucose_level        bmi  smoking_status
# 2413               0             100.42  28.893237               3
# 1141               0              90.06  28.893237               0
# 146                1              68.43  28.893237               1
# 3883               1              69.89  28.893237               0
# 1044               1              93.89  28.893237               2
# ...              ...                ...        ...             ...
# 2261               1              60.35  28.893237               1
# 4712               1              93.04  28.893237               2
# 4971               1              57.06  28.893237               2
# 2224               0              76.28  28.893237               1
# 4825               1              71.80  28.893237               0
#
# [1022 rows x 10 columns]

# %%
y_train
# Out:
# 2285    0
# 4733    0
# 3905    0
# 4700    0
# 4939    0
#        ..
# 1180    0
# 3441    0
# 1344    0
# 4623    0
# 1289    0
# Name: stroke, Length: 4088, dtype: int64

# %%
y_test
# Out:
# 2413    0
# 1141    0
# 146     1
# 3883    0
# 1044    0
#        ..
# 2261    0
# 4712    0
# 4971    0
# 2224    0
# 4825    0
# Name: stroke, Length: 1022, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
naive=GaussianNB()
naive.fit(x_train,y_train)
y_pred=naive.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
result=confusion_matrix(y_test,y_pred)
result
# Out:
# array([[862,  98],
#        [ 45,  17]])

# %%
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.860078277886497
